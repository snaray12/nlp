# %%
import random
random.seed(a=None, version=2)

# %%
import dill
import gensim
import os
from pathlib import Path
import pandas as pd
import numpy as np
import seaborn as sns
from nltk.probability import FreqDist
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from gensim.models import FastText
from gensim.models import Word2Vec
import spacy
from gensim.models import Phrases
import collections
from networkx.exception import NetworkXError
from networkx.generators.ego import ego_graph
from chinese_whispers import chinese_whispers, aggregate_clusters
import matplotlib.pyplot as plt
import networkx as nx
import markov_clustering as mc
import datetime

# %% [markdown]
# ### Loading Reviews

# %%
# Start time
print(datetime.datetime.now())
# Out:
# 2019-08-06 11:48:53.824801

# %%
#read data
df = pd.read_csv (r'C:\Users\siddhartha\Desktop\Tag Extraction Automation\V1 - Work\langid_en_300k.csv')

#filter only english data
is_df_en = df['review_langid']== 'en'
df = df[is_df_en]
# df = df.head(100)
#review text_en as DF
df = df[['review']]
# df

# %% [markdown]
# ### Pre-processing --> Bag of N-Grams-uni,bi,tri

# %%
# Start time
print(datetime.datetime.now())
# Out:
# 2019-08-06 11:48:57.250931

# %%
#load Spacy
nlp = spacy.load("en_core_web_sm")
nlp.Defaults.stop_words |= {"-PRON-","my_new_stopword2"}
def process_text(text):
    my_doc = nlp(text)
    return [w.lemma_.lower() for w in my_doc if not w.is_stop and not w.is_punct and not w.is_digit and w.is_alpha]

#unigram
df['ntext'] = df['review'].apply(process_text)
#bigram
bigram = Phrases(df['ntext'], min_count=5, threshold=2)
df['twograms'] = df['ntext'].apply(lambda x : bigram[x])
#trigram
trigram = Phrases(bigram[df['ntext']], min_count=5, threshold=2)
df['threegrams'] = df['twograms'].apply(lambda x : trigram[x])

# df.head(10)

# %% [markdown]
# ### Custom stopwords removal using "Most frequent and least frequent words as stop words"

# %%
# Start time
print(datetime.datetime.now())
# Out:
# 2019-08-06 13:53:52.652407

# %%
# Custom stop words removal using "Most frequent and least frequent terms as stop words"
fdist = FreqDist([w for row in df['threegrams'].tolist() for w in row])
fdist

custom_stops_freq = []
for word, frequency in fdist.most_common():
#     print('{};{}'.format(word, 100*round(frequency/fdist.N(), 5)))
    custom_stops_freq.append({"word":word, "distri":100*round(frequency/fdist.N(), 5)})
    
# custom_stops_freq

custom_stops_df = pd.DataFrame(custom_stops_freq)

high_f = custom_stops_df[custom_stops_df['distri'] >= 0.5]
low_f = custom_stops_df[custom_stops_df['distri'] <= 0.004]
custom_stops_df = pd.concat([high_f, low_f])
# custom_stops_df

custom_stops_list = custom_stops_df['word'].tolist()
len(custom_stops_list)

def remove_custom_stops(wordlist):
    return list(set(wordlist) - set(custom_stops_list))

df['cusstops_filtered'] = df['threegrams'].apply(remove_custom_stops)

# %%
len(custom_stops_list)
# Out:
# 156546

# %%
df.head()
# Out:
#                                               review  \
# 0  My favorite place to stay in mumbai. The staff...
# 1  The hotel has a good connection to London cent...
# 2  Went for a weekend getaway with the Mrs. Hotel...
# 3  The hotel is a perfect location to easily get ...
# 4  The hotel was very nice and well located.  We ...
#
#                                                ntext  \
# 0  [favorite, place, stay, mumbai, staff, turnove...
# 1  [hotel, good, connection, london, centre, trad...
# 2  [go, weekend, getaway, hotel, clean, kind, sta...
# 3  [hotel, perfect, location, easily, theatre, ac...
# 4  [hotel, nice, locate, enjoy, breakfast, buffet...
#
#                                             twograms  \
# 0  [favorite_place, stay, mumbai, staff, turnover...
# 1  [hotel, good, connection, london, centre, trad...
# 2  [go, weekend_getaway, hotel, clean, kind, star...
# 3  [hotel, perfect_location, easily, theatre, acc...
# 4  [hotel, nice, locate, enjoy, breakfast_buffet,...
#
#                                           threegrams  \
# 0  [favorite_place_stay, mumbai, staff_turnover, ...
# 1  [hotel, good_connection, london, centre, tradi...
# 2  [go, weekend_getaway, hotel, clean, kind, star...
# 3  [hotel_perfect_location, easily, theatre, acco...
# 4  [hotel, nice, locate, enjoy, breakfast_buffet_...
#
#                                    cusstops_filtered
# 0  {mumbai, low, comfortable, member_staff, want,...
# 1  {feel_like, pub, centre, catch, comfortable, b...
# 2  {resort, kind, awesome, take, bar, spot, searc...
# 3  {guest, help, appreciate, size, easily, theatr...
# 4  {meal, return, nice_helpful, try, person, go, ...

# %%
# import pickle
# df['cusstops_filtered'].to_pickle('df_custom_stops_cleared_300k_hotel.pickle')
# df = pd.read_pickle('df_custom_stops_cleared_300k_hotel.pickle')
# df
# df = pd.DataFrame(df)
# df.head()
# df['resultant'] = df['cusstops_filtered'].apply(lambda x : list(x))
# df

# %% [markdown]
# ### Retrain on Existing w2v and Gensim models

# %%
# Start time
print(datetime.datetime.now())
# Out:
# 2019-08-06 15:47:40.784649

# %%
corpus = [w for row in df['resultant'].tolist() for w in row]

# corpus = [w for row in df['cusstops_filtered'].tolist() for w in row]
len(corpus)
# Out:
# 4085232

# %%
fdist = FreqDist(corpus)
# fdist.most_common(10)

# Load the pretrained Model
model1 = Word2Vec.load("word2vec_model2")

stops = stopwords.words("english")
wlist = []
for item, f in fdist.items():
    if item.lower() not in stops:
        wlist.append({"word":item, "count":f})
        
words_df = pd.DataFrame(wlist)
words_df.sort_values(by="count", ascending=False, inplace=True)

# words_df.head(n=10)

def get_similarity(w):
    similar = []
    try:
        similar = model1.wv.most_similar(w)
    except KeyError:
        print(w)
    return similar

words_df['similar_words'] = words_df['word'].apply(get_similarity)
# words_df.head()

similarlist = list(zip(words_df['word'], words_df['similar_words']))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# room_clean
# stay_night
# room_small
# good_location
# definitely_stay
# staff_friendly_helpful
# bed_comfortable
# suite
# recommend_hotel
# breakfast_good
# place_stay
# location_great
# enjoy_stay
# room_comfortable
# room_floor
# room_spacious
# location_good
# hotel_great_location
# great_place
# spa
# hotel_locate
# bedroom
# housekeeping
# room_big
# highly_recommend_hotel
# comfortable_bed
# shopping
# clean_comfortable
# desk_staff
# excellent_location
# breakfast_include
# bar_restaurant
# room_clean_comfortable
# restaurant_bar
# staff_excellent
# relaxing
# tired
# location_excellent
# swimming_pool
# room_ready
# air_conditioning
# choose_hotel
# friendly_helpful_staff
# staff_amazing
# bed_comfy
# housekeep
# welcoming
# good_experience
# ground_floor
# room_size
# check_check
# shuttle
# toiletry
# staff_helpful_friendly
# executive_lounge
# standard_room
# food_drink
# definitely_recommend_hotel
# stay_week
# good_price
# room_good_size
# boutique_hotel
# comfy_bed
# good_night_sleep
# nice_view
# staff_lovely
# club_lounge
# pleasant_stay
# short_stay
# mini_bar
# free_breakfast
# change_room
# checkout
# bathroom_small
# breakfast_excellent
# room_spacious_clean
# spacious_room
# continental_breakfast
# transportation
# clean_modern
# nice_helpful
# staff_wonderful
# sightseeing
# check_time
# club_room
# hotel_situate
# mattress
# cleaning
# little_bit
# room_tiny
# room_key
# breakfast_area
# equip
# bathroom_clean
# maintenance
# double_bed
# room_rate
# tub
# pleasantly_surprised
# staff_reception
# room_clean_spacious
# wi_fi
# bathtub
# longer
# annoying
# high_floor
# second_stay
# food_restaurant
# luxury_hotel
# size_room
# have_stay
# corner_room
# closet
# thank_staff
# breakfast_ok
# housekeeping_staff
# recently_stay
# suitcase
# feel_safe
# double_room
# satisfied
# book_night
# enter_room
# love_location
# equipment
# wedding
# bedding
# fantastic_location
# cleaner
# thing_like
# staff_fantastic
# include_breakfast
# travelodge
# shopping_mall
# lobby_area
# housekeeper
# valet_parking
# checkin
# comfortable_clean
# fault_hotel
# hyatt
# breakfast_delicious
# happy_stay
# breakfast_serve
# budget_hotel
# laundry
# location_fantastic
# clean_quiet
# window_open
# early_check
# quieter
# eat_breakfast
# look_forward_stay
# complimentary_breakfast
# interested
# good_thing_hotel
# hairdryer
# clean_spacious
# room_comfortable_bed
# room_face
# massage
# mini_fridge
# easy_walking_distance
# hotel_perfect_location
# room_bit_small
# kitchenette
# room_spotless
# shop_restaurant
# eat_restaurant
# house_keeping
# hotels
# maid
# bellman
# room_appoint
# fitness_center
# room_number
# king_bed
# minute_walk_away
# public_area
# feel_like_home
# certainly_stay
# room_clean_tidy
# refrigerator
# far_good
# shower_head
# breakfast_dinner
# dining_area
# husband_stay
# prepared
# cleaning_staff
# living_room
# minibar
# hotel_excellent_location
# common_area
# shuttle_service
# coffee_maker
# late_check
# close_metro
# wardrobe
# hot_tub
# wonderful_time
# check_process
# city_view
# food_amazing
# amazing_experience
# second_day
# enjoyable_stay
# check_easy
# junior_suite
# walking
# second_time_stay
# bathroom_shower
# kettle
# walk_shower
# staff_friendly_accommodate
# drawback
# clean_staff_friendly
# guest_service
# pay_night
# good_option
# king_size_bed
# second_floor
# wife_stay
# restaurant_close
# earlier
# food_option
# second_night
# evening_meal
# close_airport
# home_away_home
# queen_bed
# concierge_helpful
# training
# nice_size
# single_room
# sofa_bed
# bit_small
# room_overlook
# street_noise
# parking_lot
# night_sleep
# deluxe_room
# entire_stay
# superior_room
# willing
# stay_enjoyable
# staycation
# repair
# concierge_desk
# probably_good
# bottled_water
# porter
# check_early
# hair_dryer
# shuttle_bus
# wifi_work
# hotel_conveniently_locate
# executive_room
# staff_exceptional
# heating
# plan_stay
# room_spacious_comfortable
# storage
# delighted
# water_park
# left
# good_deal
# lot_restaurant
# couch
# amazed
# upgrade_suite
# look_forward_return
# motel
# bathroom_large
# water_pressure
# surround_area
# tea_coffee_make_facility
# twin_room
# convention_center
# main_restaurant
# call_desk
# poolside
# walkable
# extremely_clean
# room_clean_modern
# thoroughly_enjoy_stay
# room_little_small
# maintained
# walking_distance
# seasons
# check_quick
# deliver_room
# pleasure_stay
# excited
# staff_welcoming
# quality_service
# hotel_chain
# bedroom_suite
# overnight_stay
# restaurant_walk_distance
# staff_polite_helpful
# check_desk
# restaurant_shop
# usually_stay
# clean_bathroom
# mrt_station
# bathroom_door
# place_visit
# kid_club
# middle_night
# staff_extremely_helpful
# great_customer_service
# free_shuttle
# bed_extremely_comfortable
# room_double_bed
# pool_beach
# king_room
# family_friendly
# check_smooth
# absolutely_amazing
# old_building
# low_floor
# staff_pleasant_helpful
# hesitate_stay
# definitely_book
# go_reception
# free_parking
# butler
# short_walk_away
# compare_hotel
# super_clean
# equipped
# jacuzzi
# good_location_close
# large_bathroom
# frustrating
# room_decent_size
# staff_friendly_efficient
# lovely_view
# stayed_night
# hotel_centrally_locate
# main_pool
# excellent_customer_service
# single_bed
# sheraton
# staff_go_way
# concierge_service
# free_wi_fi
# couple_night
# definitely_recommend_stay
# metro_stop
# check_tell
# hot_food
# bath_shower
# room_high_floor
# beginning
# bath_tub
# stay_overnight
# room_clean_quiet
# spacious_clean
# worried
# room_adequate
# shower_curtain
# great_night_sleep
# breakfast_choice
# food_choice
# favorite_hotel
# meeting_room
# consider_stay
# staff_super_friendly
# golf_course
# relaxation
# business_traveler
# robe
# room_immaculate
# light_sleeper
# onsite
# day_leave
# closed
# stay_longer
# little_small
# wait_come
# air_conditioner
# try_find
# easy_check
# stay_memorable
# long_walk
# lazy_river
# accomodation
# look_forward_visit
# shopping_centre
# come_london
# delicious_food
# visit_singapore
# bathroom_tiny
# resort_fee
# key_card
# stay_twice
# place_sleep
# sized
# furnished
# dining_option
# wifi_good
# return_night
# sister_hotel
# minute_later
# rooftop_pool
# concerned
# staff_encounter
# hotel_locate_close
# go_extra_mile
# nespresso_machine
# sauna
# staff_friendly_attentive
# close_subway
# varied
# traffic_noise
# want_visit
# view_amazing
# minor_issue
# fairmont
# novotel
# wifi_free
# easy_use
# exciting
# get_upgrade
# bed_pillow
# go_desk
# star_rating
# hear_noise
# inviting
# good_wifi
# great_spot
# cupboard
# helpful_friendly_staff
# slipper
# closer
# desk_clerk
# close_metro_station
# breakfast_spread
# time_paris
# busy_time
# check_p.m.
# twin_bed
# broken
# shopping_area
# vehicle
# remodel
# transit
# staying
# ask_reception
# stay_hilton
# sofitel
# spray
# little_thing
# travel_agent
# cooked_breakfast
# disney_resort
# doubletree
# water_taxi
# hampton_inn
# intercontinental
# epcot
# ibis
# golf
# lagoon
# club_level
# expedia
# waldorf

# %%
len(corpus)
# 33277 for 1000 reviews before custom stopwords
# 26966 for 1000 reviews after custom stopwords high freq
# 24090 for 1000 reviews after custom stopwords high and low freq
# Out:
# 4085232

# %% [markdown]
# ### Graph Generation from Word Embeddings

# %%
# Start time
print(datetime.datetime.now())
# Out:
# 2019-08-06 16:52:26.738399

# %%
#creating a empty graph
G = nx.Graph()

for t1, t2 in similarlist:
    for w in t2:
        G.add_weighted_edges_from([(t1, w[0], w[1])])
        
# G.edges()

# degree_sequence = sorted([d for n, d in G.degree()], reverse=True)  # degree sequence
# # print "Degree sequence", degree_sequence
# degreeCount = collections.Counter(degree_sequence)
# deg, cnt = zip(*degreeCount.items())

# fig, ax = plt.subplots()
# plt.bar(deg, cnt, width=0.80, color='b')

# plt.title("Degree Histogram")
# plt.ylabel("Count")
# plt.xlabel("Degree")
# ax.set_xticks([d + 0.4 for d in deg])
# ax.set_xticklabels(deg)


# plt.show()

for w in words_df[words_df['count'] <5]['word'].tolist():
    try:
        G.remove_node(w)
    except NetworkXError:
        print (w)
        
# G.size()
# len(G)

# %% [markdown]
# ### Creating Ego Graph for 'G'

# %%
# Ego Graph for G is G itself
# if the maximum lenght for achieveing the node length is built for the "G", then ego-graph will be producing the same graph G

# %% [markdown]
# ### Markovian Clustering using hyperparameter for 'G'

# %%
# Start time
print(datetime.datetime.now())
# Out:
# 2019-08-06 16:52:27.304754

# %%
# # with hyperparameter tuning
# nodelist = list(G)

# # then get the adjacency matrix (in sparse form)
# matrix = nx.to_scipy_sparse_matrix(G)

# # Auto hyperparameter Tuning (inflation rate)
# # perform clustering using different inflation values
# # for each clustering run, calculate the modularity
# inflation_auto = []
# for inflation in [i / 10 for i in range(12, 30)]:
#     result = mc.run_mcl(matrix, expansion=2, inflation=inflation)
#     clusters = mc.get_clusters(result)
#     Q = mc.modularity(matrix=result, clusters=clusters)
# #     print("inflation:", inflation, "modularity:", Q)
#     inflation_auto.append((inflation, Q))
    
# cols =['inflation', 'modularity']
# result_inflation_auto = pd.DataFrame(inflation_auto, columns=cols)

# # finding inflation parameter value
# inflate_value = result_inflation_auto.loc[result_inflation_auto['modularity']==result_inflation_auto['modularity'].max(), 'inflation'].iloc[0]

# # cluster using the optimized cluster inflation value
# result = mc.run_mcl(matrix, expansion=2, inflation=inflate_value)
# clusters = mc.get_clusters(result)

# # fig = plt.figure(figsize=(20,20))
# # plt.subplot(111)
# # mc.draw_graph(matrix, clusters, node_size=50, with_labels=True, edge_color="silver")
# # plt.show()

# # finding inflation parameter value
# inflate_value = result_inflation_auto.loc[result_inflation_auto['modularity']==result_inflation_auto['modularity'].max(), 'inflation'].iloc[0]
# inflate_value

# %%
#without hyperparameter tuning, average = 1.6

nodelist = list(G)

# then get the adjacency matrix (in sparse form)
matrix = nx.to_scipy_sparse_matrix(G)

# cluster using the fixed cluster inflation value
result = mc.run_mcl(matrix, expansion=2, inflation=1.6)
clusters = mc.get_clusters(result)

# %%
# End time
print(datetime.datetime.now())
# 20 mins for 1000
# Out:
# 2019-08-06 16:52:33.293555

# %%
clusters_list_of_lists = [list(elem) for elem in clusters]
row_no = list(range(len(nodelist)))
dictionary = dict(zip(row_no, nodelist))
def replace_all(word_list, dictionary):
   for i, j in dictionary.items():
      for lst in word_list: 
         if i in set(lst): 
            lst[lst.index(i)] = j

replace_all(clusters_list_of_lists, dictionary)

# %%
n = 1
for s in clusters_list_of_lists:
    print('\ncluster->', n,'\n')
    print(*s, sep = ", ")
    n=n+1
    
# 4591
# Out:
# cluster-> 1
#
# restaurant, this_restaurant, resturant, place, italian_restaurant, this_place, place_eat, liman, restaurant_london, chinese_restaurant, cheap_eat, local, japanese_restaurant, asian_restaurant, chinese_food, indian_restaurant, italian_food, one_favorite, lebanese_restaurant, restaraunt, jazz_club
#
# cluster-> 2
#
# venue, view_london, great_view, cocktail_bar, view, amaze_view, view_amaze, view_city, fantastic_view, beautiful_view, set, fabulous_view, view_incredible, stun_view, amazing_view, view_stun, wonderful_view, incredible_view, outstanding_view
#
# cluster-> 3
#
# eatery, restuarant, office_build
#
# cluster-> 4
#
# establishment, restaurant_paris, complain_lack
#
# cluster-> 5
#
# location, great_location, central_london, chill_atmosphere, nice_ambiance, worth_visit
#
# cluster-> 6
#
# dine_room, lovely_garden, downstairs, upstairs, bar, bar_area, sit_bar, hang_bar, seat_bar, door, floor, window, table_right, table_window, table_outside, outside, inside, inside_outside, table_inside, space, room, seat, sit, seat_table, corner, table_near, main_floor, rooms
#
# cluster-> 7
#
# hotel, resort, grosvenor_house, park_hyatt, jumeriah_beach, locate_street, villa, inn, manor
#
# cluster-> 8
#
# night, even
#
# cluster-> 9
#
# evening, manage_seat
#
# cluster-> 10
#
# afternoon, quaglino, visit_manhattan
#
# cluster-> 11
#
# tonight, take_friend, week, yesterday, recently, this_time, work_christmas, base_trip_advisor, ago, today
#
# cluster-> 12
#
# weekend, saturday_night, late_lunch, saturday, early_dinner, lunch_time, dinner_saturday, friday_night, saturday_even, theatre, friday_even, monday, sunday, friday, thursday, sunday_even
#
# cluster-> 13
#
# live_music, great_vibe, fun, entertainment, music, cool_place, vibe, live_band, people_watch, dj_play
#
# cluster-> 14
#
# celebrate_birthday, treat_friend, treat, birthday, celebrate_husband, friend_celebrate, wish_happy, book_aqua_shard, surprise_birthday, take_wife, celebration, anniversary, celebrate_friend, celebrate_mum, celebrate_mother, sing_happy, singe_happy, wife_birthday, celebrate, lunch_celebrate, wedding_anniversary, grandchild, birthday_treat, celebrate_year, take_partner, go_celebrate, celebrate_son
#
# cluster-> 15
#
# bottomless_brunch, dinner, brunch, supper, banquet, sunday_lunch, dinner_friend, lunch, lunch_friend, afternoon_tea, pre_theatre, visit_shard, birthday_meal, birthday_disappoint, drink_dance
#
# cluster-> 16
#
# aqua_shard, special_occasion, great_experience, celebrate_special, enjoy_experience, amaze_experience, wonderful_experience, occasion, birthday_celebration, occassion, birthday_dinner, family_gather
#
# cluster-> 17
#
# clean, fast_service, mix_people, big_space
#
# cluster-> 18
#
# quick_service, atmosphere_great, great_ambience, relax_atmosphere, friendly_staff, friendly_service, great_atmosphere, helpful_staff, attentive_staff, the_ambience, the_atmosphere, great_service, excellent_service, fantastic_service, service_excellent, attentive_service, service_superb, ambiance, atmosphere, ambience, environment, service_good, friendly_environment, selection_beer, welcome_staff, place_relax, lovely_atmosphere, wine_selection
#
# cluster-> 19
#
# nicely_decorate, good_vibe, relax, atmosphere_nice, cosy, lively, chill, hangout_friend, nice_music, lovely_relax, warm_relax, buzz_atmosphere, help_create, vibrant, warm_cosy, nice_decor, buzz, buzzy, chatter, couple_group
#
# cluster-> 20
#
# nice_atmosphere, value, good_value, value_money, price_okay, great_value, reasonably_price, reasonable_price, good_value_money, price_reasonable, great_value_money, not_cheap, price_fair, affordable, decent_price, fair_price
#
# cluster-> 21
#
# plenty_seat, ideal, american_bar, cafe_style, nice_relax
#
# cluster-> 22
#
# serve_quickly, take_forever, take_long, friendly_efficient, quick, fast, slow, prompt, little_slow, friendly_quick, bite_slow, take_age, super_quick, efficient_polite, exceptionally_friendly, quick_efficient
#
# cluster-> 23
#
# spot, nice_place, great_venue, place_chill
#
# cluster-> 24
#
# hard_rock, crowd_noisy, company, mahiki, five_fields, lunch_break, run_smoothly
#
# cluster-> 25
#
# hard_rock_cafe, city, london, dubai, paris, nyc, singapore, new_york, town, cape_town, sun_shine, bother_go, orlando, want_authentic, brooklyn, ny, seattle, manhattan, disney_spring, uae, visit_disney, disney, katz, stay_near, bice, boston, dc, this_favorite, bouley, nobu
#
# cluster-> 26
#
# need, pay_attention, bother, walk_away, point, person_serve, issue, mean, manager_come, take_order, pay_bill, apologise, come, bring, send, finally_come, leave, let, refuse, see, -PRON-_see, job, think, -PRON-_know, believe, not, actually, realise, that, not_sure, ask, ask_want, ask_waiter, tell, say, ask_bill, give, clear_table, plate_clear, wait_age, way, sort, obviously, how, ignore, -PRON-_believe, exactly, clearly, aware, when, say_yes, explain, offer_suggestion, -PRON-_understand, want_pay, hand_card, complain, when_ask, by_point, speak_manager, happen, -PRON-_notice, free_table, difficult, inform, waiter_tell, apparently, give_wrong, unfortunately, case, run, table_occupy, manage, go_downhill, keep_eye, call_waiter, refuse_pay, ask_okay, possible, keep, forget, feel_compel, acknowledge, complaint, fact, mind, remove, note, -PRON-_assume, manager_say, tip_bill, spend_minute, cram_table, notice, argue, enquire, read_menu, extremely_rude, at_point, comment, respond, answer, reply, appear, push, warn, ask_speak, little_rude, treat_badly, state, rude_way, correct, clear, struggle, question, such_shame, tell_manager, lose, situation, eye_contact, ask_waitress, no_apology, offer_discount, response, mistake, assume, insist, accept, apology, apologetic, explanation, ask_politely, admit, react, error
#
# cluster-> 27
#
# stand, problem, check, order_drink, table_ready, half_hour, arrive, wait_long, get, turn, got, wait_minute, wait_hour, arrive_minute, wait_min, get_seat, take_minute, minute_late, take, wait_line, people_wait, order_take, minute, seat_minute, desk, sit_table, right_away, tell_wait, straight_away, find_table, wait_table, hour, min, wait, wait_time, long_wait, queue, ready, minute_wait, wait_half, hour_wait, instead, finally, table, long, quickly, minute_early, late, eventually, waitress_come, after_minute, immediately, promptly, half, delay
#
# cluster-> 28
#
# little_bite, maybe, probably, -PRON-_guess, -PRON-_think, anyway, yes, but
#
# cluster-> 29
#
# like, different, differently, taste_different
#
# cluster-> 30
#
# prefer, be_regular, pay_price, personal_preference, figure
#
# cluster-> 31
#
# type, menu_limit, low_quality, base, thin_crispy, base_pizza, add_salt, food_consistent, -PRON-_usually, offer_gluten_free, speciality
#
# cluster-> 32
#
# -PRON-_love, love, adore, lover
#
# cluster-> 33
#
# try_different, try, favourite, prepare_perfectly, share_small, standout_dish, huge_fan, white_meat, die, mac_cheese
#
# cluster-> 34
#
# etc, unique_flavour, salad_pasta, large_bottle
#
# cluster-> 35
#
# fancy, if_look, well_value, if_want, a_nice, incredible_pizza, typical_french, busy_bustle, bite_different, bite_date
#
# cluster-> 36
#
# weird, bite_cold, tea_pot, silly, kind_thing, good_measure, star_review
#
# cluster-> 37
#
# anymore, the_title
#
# cluster-> 38
#
# covent_garden, near_hotel, clapham, west_end, andheri_west, eat_regularly, highly_rate, popular_restaurant, chiswick, jamie_italian
#
# cluster-> 39
#
# come_collect, collect, stand_bar
#
# cluster-> 40
#
# let_know, want_leave, table_clear, ask_check, promise, bill_ask, lie, horrible_experience, remove_bill
#
# cluster-> 41
#
# go, -PRON-_go, watch_game
#
# cluster-> 42
#
# decide, -PRON-_decide, then_ask, queue_min, there_sign
#
# cluster-> 43
#
# way_hotel, pop, walk_past, -PRON-_stumble, stop, decide_head, quick_stop
#
# cluster-> 44
#
# go_dinner, couple_day, stay_hotel, couple_month, have_lunch, wife_amp, gauthier, take_boyfriend, cape_point, march, wife_celebrate
#
# cluster-> 45
#
# bring_family, wish, -PRON-_hope, for_sure, will_not, hope, want_discount, chiquito, reason_come, -PRON-_wish
#
# cluster-> 46
#
# food, food_good, the_food, quality_food, food_fantastic, food_tasty, food_delicious, food_excellent, food_amaze, food_superb, food_okay, amazing_food, food_incredible, food_outstanding, food_faultless
#
# cluster-> 47
#
# return, visit_soon, recommend_friend, recommend, recommend_restaurant, recommend_place, reccomend, recomend, heartily_recommend, stuff_end, recommend_hutong, come_soon, go_soon, return_future, return_nyc, return_soon, come_future, soon, trip_dubai, ma_goa
#
# cluster-> 48
#
# want_eat, long_time, zizzi, trip_ny, mauritius, busaba
#
# cluster-> 49
#
# incredibly_rude, understand, mention, interact_customer, attract_attention, speak, lovely_chat
#
# cluster-> 50
#
# find, found, discern
#
# cluster-> 51
#
# discover, to_honest, regular_basis, after_month, go_shake_shack, visit_hard_rock
#
# cluster-> 52
#
# pay_lot, bear_mind, prepare_pay, sort_place, afford, want_spend
#
# cluster-> 53
#
# find_place, close, open, queue_wait, seat_face, decide_try, avoid
#
# cluster-> 54
#
# search, trip_advisor, tripadvisor, review, review_trip_advisor, read, high_expectation, write_review, have_read, bad_review, base_review, little_apprehensive, past, restaurant_tripadvisor, write, read_mix, write_bad, trip_advisor_review, read_review, review_tripadvisor, sceptical, finally_open, rave_review
#
# cluster-> 55
#
# tourist_trap, pizza_express, chain, fast_food, charlotte_street, burger_joint, hrc
#
# cluster-> 56
#
# locate, area, restaurant_grind, near, london_bridge, southwark, restaurant_locate, pike_place, locate_inside, jumeirah_beach, station, situate
#
# cluster-> 57
#
# order_wrong, hard, tough, smell_bad
#
# cluster-> 58
#
# lovely, nice, fantastic, wonderful, brilliant, fabulous, absolutely_amaze, excellent, superb, terrific, phenomenal, incredible, amazing, awesome, amaze, marvelous, perfect, great, marvellous
#
# cluster-> 59
#
# gorgeous, beautiful, delightful, exquisite, luscious, sublime, sumptuous
#
# cluster-> 60
#
# really_nice, knowledgeable_friendly, feel_home, super_nice, friendly_atmosphere, absolutely_brilliant, super_helpful, owner_friendly
#
# cluster-> 61
#
# want, do
#
# cluster-> 62
#
# able, soon_possible, time_explain
#
# cluster-> 63
#
# -PRON-_sincerely, perhaps, surely, waste_time, do_bother, one_thing
#
# cluster-> 64
#
# exceptional, outstanding, impeccable, polite_efficient, absolutely_fantastic, notch, relax_friendly, exemplary, spotless, flawless, attentive_bear, faultless, impeccable_attentive, efficient_friendly, quick_attentive, fast_friendly
#
# cluster-> 65
#
# absolutely_delicious, taste_fresh, delicious, tasty, yummy, scrumptious, delectable, delish, fresh_tasty, generous_portion, flavoursome, big_portion, big_quantity
#
# cluster-> 66
#
# look, glance, stare, table_corner, catch_attention
#
# cluster-> 67
#
# wonder, in_end, big_deal, realize, worry, stand_line, waitress_say, wait_approx, tell_advance, time_round
#
# cluster-> 68
#
# pretty, pretty_darn, although, too
#
# cluster-> 69
#
# look_like, dirty, high_rate, avoid_cost, filthy, horrid, dark_inside, pathetic, unhygienic, grubby, dingy, shabby, drab, tacky, exceptionally_busy, scruffy, tatty
#
# cluster-> 70
#
# small, large, big, huge, upper_west, mean_share, massive, smallish, choice_side, only_negative, struggle_finish, maybe_well, slightly_small
#
# cluster-> 71
#
# tiny, picture_window, sit_middle, table_clothe, type_thing, tiny_bite, pay_dollar
#
# cluster-> 72
#
# size, tasty_portion, portion_right, portion_size
#
# cluster-> 73
#
# tiny_table, board, celebrate_engagement, vegetarian_menu, egg_toast
#
# cluster-> 74
#
# street, park, downtown, neighborhood, high_street, mayfair, walk_distance, dubai_mall, road, tuck_away, locate_near, eiffel_tower, marylebone, hide_away, midtown, piccadilly, avenue, district, dine_option
#
# cluster-> 75
#
# nearby, time_square, open_late
#
# cluster-> 76
#
# wow, more_importantly, literally_well
#
# cluster-> 77
#
# really_good, very_good, good_quality, very_tasty, consider_quality, large_portion
#
# cluster-> 78
#
# love_place, amazing_atmosphere, turkish_food
#
# cluster-> 79
#
# if_like, last_day, real, fresh_ingredient, genuine_italian
#
# cluster-> 80
#
# kid_love, real_italian, nepalese, italian_pizza, lovely_environment, staten_island, cool_atmosphere, kid_adult, pizza_salad, chef_cook
#
# cluster-> 81
#
# enjoy, savor, revel, crave
#
# cluster-> 82
#
# if_love, fine_indian, this_far, country, region, great_concept
#
# cluster-> 83
#
# book, book_table, book_month, book_week, advance, reservation, need_book, able_table, book_advance, make_reservation, booking, booked, month_advance, sunday_morning, schedule, hour_probably, way_advance, able_book
#
# cluster-> 84
#
# arrive_early, reserve_table, book_online, table_book, drink_bar, give_table, get_table, early, chance, open_table, dinner_reservation, pre_book, party, p.m., reserve, manage_table
#
# cluster-> 85
#
# experience, dine_experience, truly, expereince, experince, truly_unforgettable, step_restaurant
#
# cluster-> 86
#
# overall_experience, all_round, efficient_service, little_pricy, casual_atmosphere, value_money_will, variety_menu
#
# cluster-> 87
#
# aspect, although_bite, element, culinary_experience, factor, component
#
# cluster-> 88
#
# certainly, level, have_say, yes_expensive, pretty_high, read_comment, probably_will, absolutely, far_superior, guarantee
#
# cluster-> 89
#
# knowledge, sommeli, expertise
#
# cluster-> 90
#
# work, 2_home, feel_like, make_feel, need_worry
#
# cluster-> 91
#
# business, feel_oblige
#
# cluster-> 92
#
# hard_work, welcome_smile, big_thank, great_host, greet_smile
#
# cluster-> 93
#
# spend_time, talk, conversation, listen, laugh, chat, have_fun, young_child, check_sure, romantic_meal, short_wait, sing, just_think
#
# cluster-> 94
#
# good_job, work_hard
#
# cluster-> 95
#
# meet_friend, very_quiet, perfect_place, romantic_dinner, business_dinner, place_spend, have_wonderful, week_end, way_spend, have_breakfast
#
# cluster-> 96
#
# clearly_want, lady_desk, table_overlook, house, sandwich_fresh, immediately_feel, young_waitress
#
# cluster-> 97
#
# work_guy, great_personality, customer_service, service, waiter_antonio, pay_attention_detail, brunch_dubai, waiter_attentive
#
# cluster-> 98
#
# visit, vist, visited, work_door
#
# cluster-> 99
#
# visit_london, trip, visit_paris, visit_new_york, live_london, visit_nyc, bubba_gump_shrimp, plan_visit, plan_return, eat_dishoom, visit_city, visit_orlando
#
# cluster-> 100
#
# bring_friend, family, family_friend, group_friend, date_night, friend_family, bring_kid, night_friend
#
# cluster-> 101
#
# bed, baby_chicken, serve_bowl, bread_basket, neer_dosa, rock_hard, son_enjoy
#
# cluster-> 102
#
# fry_egg, scramble_egg, bake_bean, amp_garlic, roast_tomato, truffle_oil, salad_grill, home_fry, both_amaze, corn_bread
#
# cluster-> 103
#
# hot_soup, pile_high, knife_fork, red_green, leg, thigh, ribs, batter_fish, cook_lamb, shoulder, bone
#
# cluster-> 104
#
# sushi_roll, braise_pork, ball, rice_ball, order_rib, red_pepper, bake_alaska, batter
#
# cluster-> 105
#
# request, wait_nearly, show_bar, advise, consult, instruct, kitchen_close
#
# cluster-> 106
#
# pool, lounge_area, seat_area, outdoor_seat, outside_area, beer_garden, sit_area, view_empire_state, indoor, bar_downstairs, low_light, bright_light, outdoor, nice_cozy, smoke_area
#
# cluster-> 107
#
# gift_shop, weather_nice, location_convenient, go_theater
#
# cluster-> 108
#
# natural_light, sound, bite_dark, quality_meat
#
# cluster-> 109
#
# patio, sit_outside, terrace, balcony, roof_terrace, courtyard, deck, garden, lovely_summer
#
# cluster-> 110
#
# bathroom, restroom, toilet, washroom, loo, urinal
#
# cluster-> 111
#
# dine_area, basement, ceil, stair, grind_floor, main_dine, 2_floor, sit_near, bite_chilly, street_level, open_plan, entrance, high_ceiling, depend_sit, high_ceil, wall, dark_wood, section
#
# cluster-> 112
#
# bar_staff, bartender, barman, bar_tender, care_guest
#
# cluster-> 113
#
# host_birthday, not_bad, deal, pay_half, head, view_platform
#
# cluster-> 114
#
# whilst_walk, escape, review_say, walk_round, after_spend
#
# cluster-> 115
#
# bus_stop, sand_lake, corridor, east, west, south, north, northwest, southern, western
#
# cluster-> 116
#
# receive, forget_drink
#
# cluster-> 117
#
# provide, deliver, provide_excellent, fill_glass, professional_friendly, question_ask
#
# cluster-> 118
#
# offer, available, sensible_price, fix_price, set_meal, a_la_carte, lunch_set, order_la_carte, excellent_value, excellent_value_money, limit, fix_menu, restrict, quality_presentation
#
# cluster-> 119
#
# include, plus, dessert_bottle, course_bottle, aed
#
# cluster-> 120
# option, menu_offer, plenty, nice_selection, good_variety, good_choice, good_selection, selection, great_variety, cold_warm, great_choice, lot_choice, wide_selection, great_selection, plenty_variety, lot_variety, lot_choose, hard_choose, include_bottle
#
# cluster-> 121
#
# offering, price_possibly, offer_wide, delicious_unusual, classic_french
#
# cluster-> 122
#
# choose, order_different, select_dish, course_taste, al_la_carte, opt, please_choice, order_appetizer, partner_order, selection_different, offer_pre, not_suitable
#
# cluster-> 123
#
# set_menu, starter_main, choice, taste_menu, course, course_desert, match_wine, set_lunch
#
# cluster-> 124
#
# walk, book_problem
#
# cluster-> 125
#
# enter, immediately_get, upon_arrive, reach_restaurant, entire, whole, first_let, private_dine, arrive_saturday, ask_window
#
# cluster-> 126
#
# wander, wait_outside, want_sit, entrance_restaurant, stumble
#
# cluster-> 127
#
# seat_right, move, pass, away
#
# cluster-> 128
#
# europe, uk, india, hong_kong, usa, european, france, spain, greece, japan, belgium, switzerland, brazil
#
# cluster-> 129
#
# enjoyable, thoroughly_enjoy, lot_fun, thank_lovely, really_enjoy, what_wonderful, memorable, pleasurable, truly_enjoy, thoroughly_enjoyable, absolutely_perfect, expensive_worth, have_lovely, karibu
#
# cluster-> 130
#
# enjoy_meal, remember, girl_friend
#
# cluster-> 131
#
# recently_celebrate, impress, excite, disappoint_the, extremely_impress
#
# cluster-> 132
#
# perfectly, perfection, cook_perfection, beautifully_cook, red_wine, steak_cook, beef_cook, grill_octopus, perfection_side, melt_mouth, cook_absolute
#
# cluster-> 133
#
# people, everybody, somebody, everyone, anybody, nobody, people_meet, me, day_work, anyone
#
# cluster-> 134
#
# person, order_alcohol
#
# cluster-> 135
#
# customer, staff_member, the_manager, member_staff, manager, hostess, supervisor, lady, girl, receptionist, young_gentleman, young_lady, woman, young_man, employee, worker, the_hostess, head_waiter, face, after_min, personnel, young_waiter, nurse, coworker, warm_greet
#
# cluster-> 136
#
# group, small_party, couple, fairly_quiet, few, thing_note, large_group, ask_move, rush_meal
#
# cluster-> 137
#
# the_waitress, waitress, waiter, the_waiter, wait_staff, server, staff
#
# cluster-> 138
#
# friends, friend, pal, buddy, dear_friend
#
# cluster-> 139
#
# child, children, toddler, teenager, tot, teen
#
# cluster-> 140
#
# comfortable, loud_hear, relaxed, relaxed_atmosphere, jovial
#
# cluster-> 141
#
# feel_comfortable, feel_ease, feel_relax, old_friend, moment_arrive, waiter_polite, entire_experience, moment_leave, good_spirit
#
# cluster-> 142
#
# place_clean, warm, create_wonderful, waitress_sing, calm_peaceful, waitress_kind
#
# cluster-> 143
#
# atmosphere_relax, charming, unpretentious, charm, homely, genuinely_friendly, amiable, adorable, cosy_warm
#
# cluster-> 144
#
# cozy, intimate, romantic, look_romantic, sit_garden
#
# cluster-> 145
#
# glass_lift, tower_bridge, south_bank, burj_khalifa, rooftop, white_house, orchard_road, outside_terrace, harbour, st_pauls, southbank, thames, roof, paul_cathedral, st_paul
#
# cluster-> 146
#
# thank, special_thank, thank_guy, thankyou, like_thank, congratulate, great_job, staff_especially, a_special, soon_thank, take_care, happy, team, a_big, staff_management, night_memorable, sulekha, giuseppe, even_special, great_entertainment
#
# cluster-> 147
#
# definitely_come, highly_recommend, will_come, definitely_recommend, nice_ambience, definitely_visit, -PRON-_highly_recommend, would_recommend, would_highly_recommend, amazing_place, definitely_go, ambiance_great, pricey_worth, certainly_visit, what_lovely
#
# cluster-> 148
#
# magnificent, splendid, breath_take, montmartre, stunning, breathtaking, spectacular, sensational, absolutely_stun, dramatic, grand, jaw_drop, small_intimate
#
# cluster-> 149
#
# elegant, nice_calm, decor, interior_design, old_world, modern, the_interior, the_decor, design, interior, decoration, layout, décor, classy, stylish, cool_relax, elegance, design_restaurant
#
# cluster-> 150
#
# suggest, catch_eye, great_knowledge, pre_select, offer_recommendation, help_select
#
# cluster-> 151
#
# lot, some, family_style, lot_different
#
# cluster-> 152
#
# there_lot, alternative, u_eat, limit_choice
#
# cluster-> 153
#
# other, one, come_hungry, introduce_new, hoboken
#
# cluster-> 154
#
# variety, vegetarian_option, range, variety_food, lot_option, wide_variety, wide_range
#
# cluster-> 155
#
# good_thing, hear, review_decide, -PRON-_hear, hear_good, -PRON-_imagine, -PRON-_afraid, have_hear
#
# cluster-> 156
#
# normally, usually, generally, typically, tend, sometimes, often, seem, to_conclude, frequently, necessarily, rarely, seldom, occasionally, new_yorkers, invariably
#
# cluster-> 157
#
# idea, thing, something, so, now
#
# cluster-> 158
#
# kind, fake_smile, attitude, serve_alcohol, rude, arrogant
#
# cluster-> 159
#
# guest, michel_roux
#
# cluster-> 160
#
# take_time, ready_help, help, go_way, smile, feel_welcome, accommodate, attentive_need, experience_unforgettable, polite_friendly
#
# cluster-> 161
#
# show, reception, show_table, when_arrive, seat_immediately, arrival
#
# cluster-> 162
#
# warmly_greet, as_soon, enter_restaurant, open_door, hospital, escort_table, seat_promptly, moment_step, upon_arrival
#
# cluster-> 163
#
# greet, host, arrive_greet
#
# cluster-> 164
#
# know, people_complain, clue
#
# cluster-> 165
#
# price, cheap, expensive, price_high, overprice, consider_price, worth_price, bite_pricey, worth_money, worth_penny, little_expensive, relatively_expensive, price_pay, pricey, pricy, little_pricey, bite_expensive, pay_view, worth, totally_worth, spend, reasonable, normal_price, overpriced, pricey_pay, compare_london
#
# cluster-> 166
#
# prices, pricing
#
# cluster-> 167
#
# cost, happy_pay, receive_discount, pay_extra, bill_come, expect_pay, end_pay, total_bill, bill_arrive, steak_side, dollar, pound, burger_chip
#
# cluster-> 168
#
# reason, why, because
#
# cluster-> 169
#
# sure, will, amazingly_delicious
#
# cluster-> 170
#
# check_okay, explain_menu, take_coat, need_help, recommendation, great_recommendation, suggestion, advice, server_knowledgeable, knowledgeable_menu, assist, answer_question, fab_night, help_choice, recommend_anybody, great_suggestion, guy_serve, offer_advice, guide, helpful_smile, passionate_food, kindly, graciously, politely
#
# cluster-> 171
#
# lobby, reception_area, garden_area
#
# cluster-> 172
#
# upon_enter, glass_window, far_away, seat_inside, large_window, door_open, 2_level, bite_cramp, air_condition, control, even_progress, table_chair, seat_close, only_slight, edge, outside_door, man_woman, umbrella, admire_view, disappoint_on, narrow, occupy
#
# cluster-> 173
#
# seat_near, block, downstairs_bar, people_stand, hole, park_car, large_room, do_fool
#
# cluster-> 174
#
# high_chair, make_wonder, chair, barely_hear, person_sit
#
# cluster-> 175
#
# want_try, eat, hungry, consume, travel_far
#
# cluster-> 176
#
# try_new, live, visit_ny, have_live
#
# cluster-> 177
#
# big_fan, fan, stax, -PRON-_crave, italian_market, junk_food, fanatic, live_hype, seafood_lover
#
# cluster-> 178
#
# miss, word_describe
#
# cluster-> 179
#
# expect, consider, recommend_avoid, fairly_expensive
#
# cluster-> 180
#
# average, okay, ok, pretty_good, alright, write_home, decent, justify_price, fine, decent_value, good, okay_special, okay_price
#
# cluster-> 181
#
# high_price, far_well, rate, expect_high, high_end, term_quality, in_opinion, certainly_well, michelin_star, difference, fine_dine, well_japanese
#
# cluster-> 182
#
# food_average, lack, no_smile
#
# cluster-> 183
#
# fairly, quite, maybe_little, relatively, reasonably, obviously_busy, staff_cope, unusually, give_location
#
# cluster-> 184
#
# amp, bread_starter, like_decoration, bodz, never_mind, wide_spread, abusan, garlic_prawn, very_romantic, celebrate_occasion, highly_recommended
#
# cluster-> 185
#
# feel, feeling, feel_little, felt, mood, only_thing, dream_come
#
# cluster-> 186
#
# lack_atmosphere, good_sign, little_cramp, fit, seat_comfortable, huge_disappointment, bite_pretentious, particularly_busy
#
# cluster-> 187
#
# slightly, noticeably, marginally, food_alright
#
# cluster-> 188
#
# somewhat, service_ok, admittedly, nonetheless, lunchtime_menu, nevertheless, albeit, restaurant_nearly
#
# cluster-> 189
#
# shower, away_window, play_game, just_pop, bathe
#
# cluster-> 190
#
# bath, affogato
#
# cluster-> 191
#
# couple_hour, year_finally, after_day, family_vacation, very_popular, numb_people, small_kid
#
# cluster-> 192
#
# especially, particularly, high_quality, quality_ingredient, nicely_present, beautifully_present, size_portion, menu_vary, extremely_prepare, presentation, bottle_malbec, decent_size, portion_perfect
#
# cluster-> 193
#
# very_nice, great_ambiance, fab, view_awesome, very_friendly
#
# cluster-> 194
#
# waiter_take, drink_refill, -PRON-_advise, big_group, couple_drink, the_bartender, make_sure, do_hesitate, broadway_show, seem_like
#
# cluster-> 195
#
# party_arrive, rude_waiter, straight, within_minute, elderly_man, true_word
#
# cluster-> 196
#
# absolute_delight, extremely_welcome, meet_need, ease, total_experience, take_photo, incredibly_attentive, courteous_attentive, unbelievable_experience, attentive_polite
#
# cluster-> 197
#
# truly_outstanding, remarkable, unbelievable, unreal, consistently_excellent, extraordinary, truly_amaze, truly_excellent, friendly_informativesave_money, stay_away, tgi, time_money, deserve_michelin_star, -PRON-_rarely, count, pay_premium, food_ok, tastecard
#
# cluster-> 208
#
# cover_charge, matter, hard_hear
#
# cluster-> 209
#
# leave_tip, cash, suppose, say_pay, card, credit_card, accept_credit, get_bill, tip_add, discretionary_service, payment, refund, receipt, debit_card, hard_earn, wee_bite, deposit
#
# cluster-> 210
#
# customer_right, care_customer, train, attention_give, try_hard, pay_customer, picture_wall, sound_like, ask_help, more_like
#
# cluster-> 211
#
# little, bit, tad, eat_half, serve_cold, share_side, bite_heavy, fall_apart, boil_egg
#
# cluster-> 212
#
# bite, chew
#
# cluster-> 213
#
# quiet, noisy, table_close, space_floor, cool, bite_loud, loud_music, great_tune, noise, loud, music_loud, loud_noise, little_loud, crowd, able_hear, pretty_loud, play, jazz_band, start_play, start_dance
#
# cluster-> 214
#
# very_busy, wait_seat, get_busy, bite_crowd, get_crowd, popular, fill_fast
#
# cluster-> 215
#
# morning, bank_holiday, open_hour
#
# cluster-> 216
#
# decide_eat, head_airport, head_home, tour, reservation_available, early_morning, saturday_morning
#
# cluster-> 217
#
# new_years, christmas, new_year, plan, small_group, mid_week, gem_bar, xmas, decide_celebrate, mother_birthday
#
# cluster-> 218
#
# facility, plant, warehouse
#
# cluster-> 219
#
# center, outdoor_sit, location_close
#
# cluster-> 220
#
# site, downtown_disney, roof_bar, gordon_ramsay, raffles_hotel, plan_ahead
#
# cluster-> 221
#
# car_park, warm_weather, metro_station, right_door, animal_kingdom, short_walk, train_station, restaurant_situate, central_park, liverpool_street, food_court, request_table, bishopsgate, conveniently_locate, london_eye, tottenham_court_road, transport, putney, location_near, easy_access, locate_right, nice_outdoor, tube_station, shop_centre, mrt, knightsbridge, cancel_reservation, easy_walk, oxford_street, east_village, selfridges, marriott, small_street, every_minute, distance, directly_street, hyde_park, magic_kingdom, bank
#
# cluster-> 222
#
# building, upgrade, revamp, refurbish, so_yes, build, renovation, renovate, refurbishment, construction, makeover, refit, project, redo, construct, expansion, demolish, rebuild, spruce, refurb
#
# cluster-> 223
#
# consist, menu_include, pretty_big, comprise, prawn_scallop, soup_delicious
#
# cluster-> 224
#
# -PRON-_prefer, right_size, pre_cook, heavy, moist_inside, nicely_cook, medium_size, white_sauce, veg_curry
#
# cluster-> 225
#
# large_piece, there_option, kid_meal, ton, if_hungry, huge_slice, crab_leg, chicken_pot, other_dish
#
# cluster-> 226
#
#
#
# service_poor, serve_fast, fair, honest, but_overall, try_thai, service_okay
#
# cluster-> 249
#
# travel, visit_ellen
#
# cluster-> 250
#
# business_trip, favorite_restaurant, lunch_whilst, recent_trip, balthazar, whilst_stay, day_walk, the_wolseley, day_trip, week_trip, different_location
#
# cluster-> 251
#
# vacation, partner_birthday, final_night, honeymoon, visit_aqua_shard, wed, take_mum, celebrate_anniversary
#
# cluster-> 252
#
# new, place_visitor, menu_change, relax_fun
#
# cluster-> 253
#
# change, alter
#
# cluster-> 254
#
# try_test, counter_seat, learn, teach, ocean_basket
#
# cluster-> 255
#
# excite_find, explore, jumeirah, time_explore, recently_move, positive_review, the_ivy, soak_atmosphere
#
# cluster-> 256
#
# old_style, rare_find, familiar, unfamiliar, north_african, not_expensive, middle_east, casual_dine
#
# cluster-> 257
#
# four_seasons, low_manhattan, atlantis, in_heart, marina_bay, make_trip, found_farmers
#
# cluster-> 258
#
# make, francesco, romantic_atmosphere, u_feel, the_deco
#
# cluster-> 259
#
# create, fresh_natural, inspire, the_architecture
#
# cluster-> 260
#
# excellent_job, professionalism, excellence, skill, excel, succeed, compete, thrive, perform
#
# cluster-> 261
#
# amenity, welcome_environment, real_bonus, beautiful_decor, surrounding, setting, the_ambiance, decor_beautiful
#
# cluster-> 262
#
# waterfront, beach, burj_al_arab, sit_relax, bridge, river, lake, canal, creek, riverside, pond
#
# cluster-> 263
#
# view_sea, dining, restaurants, food_lover, deserve_reputation, din_experience
#
# cluster-> 264
#
# marina, boat, pier, ship, yacht, dock, outside_space, waterside, wharf
#
# cluster-> 265
#
# central_location, watch_world, convenient_location, nice_location, just_wish, lively_atmosphere, able_walk, location_ideal, lay_atmosphere, delaunay, walk_river, perfect_spot, this_pub
#
# cluster-> 266
#
# early_even, early_bird, adult_child, stop_lunch, weather_good, saturday_afternoon, sunday_afternoon, mothers_day, outdoor_table, moderately_price, be_busy
#
# cluster-> 267
#
# end_stay, long_day, catch, bar_club
#
# cluster-> 268
#
# thursday_night, afternoon_even, stumble_place, disney_springs, so_glad, business_meet, late_breakfast, numb_occasion
#
# cluster-> 269
#
# book_early, dinner_drink, start_even, club, dance_floor, place_buzz, live_dj, mix_crowd, bite_quiet
#
# cluster-> 270
#
# catch_friend, close_hotel, quick_bite, late_night, quick_drink, drink_snack, go_early, summer, hampstead
#
# cluster-> 271
#
# poor_quality, acceptable, surprisingly_good, service_terrible, average_well
#
# cluster-> 272
#
# pretty_average, typical, cafeteria_style, solid, martini, fab_cocktail, night_cap
#
# cluster-> 296
#
# happy_hour, half_price, bartender_friendly, pre_dinner, post_dinner, generous_pour, yard_house
#
# cluster-> 297
#
# alcohol, very_reasonable, small_bottle, booze, liquor, order_jug
#
# cluster-> 298
#
# glass_wine, bottle_water, bottle_wine, course_meal, dessert_coffee, extra, waiter_bring, champagne, glass_prosecco, include_glass, small_glass, glass_champagne, total, bubbly, complimentary_glass, course_glass, expensive_bottle
#
# cluster-> 299
#
# mumbai, south_indian, delhi, indian, really_interest
#
# cluster-> 300
#
# abu_dhabi, al, ali, amal, ben, moroccan, abdul
#
# cluster-> 301
#
# street_hotel, visitor, upper_level
#
# cluster-> 302
#
# end, finish, finish_meal, nice_touch, end_meal, lovely_touch, write_chocolate, happy_anniversary, give_complimentary, bring_free, happy_birthday, birthday_dessert, end_even, gift, birthday_girl, valentine, birthday_plate, write_happy, give_free
#
# cluster-> 303
#
# when_finish, water, glass_water, refill, ice_water, refill_water, tap_water, ask_twice
#
# cluster-> 304
#
# by_time, starter_arrive, take_min, then_wait, sit_minute, tell_minute, take_hour, when_finally, during_time, half_way
#
# cluster-> 305
#
# waitress_ask, then_take, pick, lobster_burger, bring_new, make_sense, load, pizza_topping, difficult_eat
#
# cluster-> 306
#
# -PRON-_opt, for_main, follow, steak_frite, t_bone, both_cook, full_flavour, for_starter, age_beef, lamb_dish
#
# cluster-> 307
#
# start, order_starter, then, starter, order_duck, main_course, main_dish, appetiser, main_meal, main, main_share, plate_remove
#
# cluster-> 308
#
# begin, despite_have, offer_glass
#
# cluster-> 309
#
# finish_starter, only, find_hair, rest, waiter_inform, rest_meal, service_appall, forget_order, waiter_ask
#
# cluster-> 310
#
# order, nearly_finish, order_entree, eventually_come
#
# cluster-> 311
#
# luncheon, met, conference, meeting, press, forum, birthday_lunch, discuss, session
#
# cluster-> 312
#
# update, at_time, try_luck
#
# cluster-> 313
#
# plus_wine, main_desert, white_red, excellent_choice, suit_taste, slightly_expensive, cheap_bottle, exactly_expect, buffet_option, waitress_suggest, include_cocktail
#
# cluster-> 314
# standard, maintain_high, reasonable_value
#
# cluster-> 315
#
# quality, quantity
#
# cluster-> 316
#
# basic, price_steep, self_service, term, michelin, non, food_wise
#
# cluster-> 317
#
# high_standard, world_class, pleasurable_experience, class, attentive_obtrusive, attentive_kind, satisfactory, view_outstanding, enjoyable_even, excellent_quality, locate_basement, overall_average
#
# cluster-> 318
#
# extremely_high, what_expectsmall_plate, item, half_portion, plate, prawn_linguine
#
# cluster-> 336
#
# polite_helpful, speak_english, extremely_attentive, attentive_professional, kind_helpful, polite_professional, attentive_prompt, welcome_attentive
#
# cluster-> 337
#
# pleasant, prompt_friendly
#
# cluster-> 338
#
# attentive_intrusive, thank_make, extra_special, even_thank, absolutely_fabulous, start_finish, professional_attentive
#
# cluster-> 339
#
# far
#
# cluster-> 340
#
# head_include, price_point, wine_expensive, premium, cost_euro, expensive_average, two_course
#
# cluster-> 341
#
# rainforest_cafe, adventure, -PRON-_confess, if_fancy, cost_head
#
# cluster-> 342
#
# busy, restaurant_busy, place_busy, pack
#
# cluster-> 343
#
# place_pack, long_queue, attention, atmosphere_inside, air_con, singe_waiter, polite_welcome, rush_foot, seat_quickly, bartender_drink, lucky_table, time_spend
#
# cluster-> 344
#
# share, dish_share, share_starter, size_large, meat_platter, platter
#
# cluster-> 345
#
# special, valentine_day, come_weekday
#
# cluster-> 346
#
# serve, serving, prepare, bring_table, server_explain, come_quickly, hot_present, preparation, customise
#
# cluster-> 347
#
# finally_arrive, cold
#
# cluster-> 348
#
# shift, departure, depart, absence, revelation, introduction, decision, abrupt
#
# cluster-> 349
#
# pre_prepare, surprise, surprise_cake, birthday_candle, suprise, look_website, celebration_friend, to
#
# cluster-> 350
#
# glass, order_bottle, bottle, wine_glass, pour_glass, glass_red, buy_bottle, glass_house, house_red, glass_white
#
# cluster-> 351
#
# optional_service, receive_bill, charge_extra, check_bill, bite_odd, card_machine, extra_charge, main_side, ask_server, take_account
#
# cluster-> 352
#
# sunny_day, early_breakfast, heron_tower, rooftop_bar, day_london, socialise, stop_brunch, wed_reception
#
# cluster-> 353
#
# owner, give_tip
#
# cluster-> 354
#
# management, deal_customer, interaction, communication
#
# cluster-> 355
#
# coffee, tea, espresso, cappuccino, latte, smoothie, teas, white_tea
#
# cluster-> 356
#
# juice, orange_juice, freshly_squeeze, pot_tea, fresh_squeeze, fresh_orange, apple_juice, milk, dairy, sugar
#
# cluster-> 357
#
# flat_white, -PRON-_forgive, run_away, say_sorry, rude_staff, coffee_machine, baby_change, bite_annoy, incompetent_staff, people_line
#
# cluster-> 358
#
# scone, cake, ice_cream, chocolate, caramel, cheese_cake, chocolate_cake, birthday_cake, cheesecake, little_sweet, pastry, carrot_cake, salt_caramel, dark_chocolate, lemon_cake, custard, crepe, key_lime, vanilla_ice_cream, sorbet
#
# cluster-> 359
#
# big_eater, stuff, italian_tapa, the_guacamole, bread_stick, everything_taste, wow_so, dessert_yummy, as_starter
# shake_hand, waiter_waitress, waiters
#
# cluster-> 380
#
# half_board, the_delaunay, similar_experience, lincoln_center, centrally_locate, le_gavroche, empire_state_building, stay_open, have_afternoon_tea, savoy_grill
#
# cluster-> 381
#
# gem_restaurant, entire_staff, enjoyable_experience, function, add_experience, begin_end, rock_roll, unforgettable_experience, regular_stop
#
# cluster-> 382
#
# vip, hilton, christina, disneyland, monica, diana, las_vegas, megan, ethan, gallagher, zuma
#
# cluster-> 383
#
# high_level, fall_short, star_hotel, favour, as_long, extremely_disappoint, heston, rank_well, step_foot
#
# cluster-> 384
#
# outside_seat, sit_inside, warm_day, sun, sunshine, sunny
#
# cluster-> 385
#
# lounge, hallway, sofa, fireplace, doorway, foyer, alcove, dining_room, banquette, sit_booth, atrium
#
# cluster-> 386
#
# private_room, room_large, nicely_lay, low_level, overlook_river, tv_screen
#
# cluster-> 387
#
# sit_downstairs, open_window, staff_ensure, find_interest, edge_restaurant, lot_space, friend_catch, in_winter, sit_window
#
# cluster-> 388
#
# daughter_birthday, month_old, a_group, pay_deposit, family_member, christmas_dinner, invite_friend, girlfriend_birthday
#
# cluster-> 389
#
# receive_apology, sorry, absolutely_appall, moment_late
#
# cluster-> 390
#
# meal, lunch_deal, dessert_house
#
# cluster-> 391
#
# definitely_worth, absolutely_worth, will_disappoint, certainly_will, well_worth, certainly_worth, always_worth, would_love, definately_worth, cost_expensive
#
# cluster-> 392
#
# elevator, escalator, subway, subway_station, rail, railway_station, railway, alleyway
#
# cluster-> 393
#
# staircase, parking, plaza, sidewalk, boulevard, walkway, boardwalk, fountain
#
# cluster-> 394
#
# lift, lift_floor, ask_sit, eye_water, usher_table, on_enter
#
# cluster-> 395
#
# extremely, awfully, very, incredibly, unbelievably, exceptionally, exceedingly, amazingly, terribly, insanely, ridiculously, overly
#
# cluster-> 396
#
# chilly, wet, damp, soggy
#
# cluster-> 397
#
# warmth, friendliness, gratitude, honesty, kindness, generosity, politeness, real_credit, satheesh, credit_company
#
# cluster-> 398
#
# hot_fresh, cook_present, plentiful, abundant, freshly_prepare, tasty_fresh, abundance
#
# cluster-> 399
#
# right_balance, crisp, smooth, correct_temperature, perfectly_balance, dessert_share, particular_highlight, grill_seabass
#
# cluster-> 400
#
# michelin_star_restaurant, hit_miss, that_s, expectation, food_mediocre, saturday_lunchtime, give_star, doubt, cheap_worth
#
# cluster-> 401
#
# service_slow, despite, once_seat, whilst, while
#
# cluster-> 402
#
# awful_awful, disgrace, unacceptable, ridiculous, absurd, bare_mind, more, a_lot, bite_apprehensive
#
# cluster-> 429
#
# architecture, art_deco
#
# cluster-> 430
#
# second, third, about_minute, min_late, first, after_wait
#
# cluster-> 431
#
# do_expect, mind_pay, product, although_little, mass_produce, wine_champagne, brasserie_style, cheese_charcuterie
#
# cluster-> 432
#
# light, bright, modern_clean, old_build, lighting, ambiance_nice
#
# cluster-> 433
#
# dark
#
# cluster-> 434
#
# light_airy, plenty_space, set_beautiful, despite_busy, floor_ceil, lay, feel_intimate, soft_music, din_room, live_piano, add_atmosphere, rise_petal
#
# cluster-> 435
#
# watch_sun, curtain, stage, spacious_table
#
# cluster-> 436
#
# open_fire, lot_memorabile, glass_door, display, fairy_light, play_music
#
# cluster-> 437
#
# rainy_day, sign_say, dempsey, from_outside, brand_new, decide_pop, adjacent_table, lot_local
#
# cluster-> 438
#
# guess, leave_bad, rude_waitress, travel_world, in_short, accuse_lie, -PRON-_bet, trust, total_waste, live_dubai, double_check, finally_decide
#
# cluster-> 439
#
# course_dessert, dessert, desert, desserts, pudding, tiramisu, chocolate_fondant
#
# cluster-> 440
#
# towel, napkin, pillow, warm_water
#
# cluster-> 441
#
# coat, complain_manager, hair, beard, skin, keep_say, water_ask, call_manager
#
# cluster-> 442
#
# blanket, candle_table
#
# cluster-> 443
#
# bag, take_away, when_eventually, completely_cold, cream_soda, machine, box
#
# cluster-> 444
#
# water_glass, hot_water, steep_stair, feel_necessary, finger_bowl, small_touch, hard_surface, no_alcohol, table_cram, power
#
# cluster-> 445
#
# table_cloth, cover, offer_water, side_include, waiter_suggest, card_payment
#
# cluster-> 446
#
# encourage_order, new_diner, direction, teethe_problem, previous_day
#
# cluster-> 447
#
# entertain, sing_song, helpful_polite
#
# cluster-> 448
#
# funny, rest_staff, sense_humour, hilarious, humorous, pleasure_meet
#
# cluster-> 449
#
# meet, have_book, attend, meet_new, celebrate_daughter, able_accommodate
#
# cluster-> 450
#
# invite, first_impression, tuesday_even, book_private
#
# cluster-> 451
#
# general_manager, gentleman, lovely_lady, member, huge_smile, big_smile, maitre_have, management_team, say_hello
#
# cluster-> 452
#
# there_space, tight, squeeze, cool_school, sit_close
#
# cluster-> 453
#
# hopefully, jbr, baku
#
# cluster-> 454
#
# mediocre, disappointing, uninspiring, unimpressive, disastrous, shocking, subpar
#
# cluster-> 455
#
# shop, store, coffee_shop, deli, mall, supermarket, grocery_store, bakery, ideally_locate
#
# cluster-> 474
#
# spacious, roomy, airy, sleek
#
# cluster-> 475
#
# restaurant_attractive, visible, noticeable, armani_hotel, thing_notice
#
# cluster-> 476
#
# quiet_street, easy_reach, railway_arch, coming_going, memorable_meal
#
# cluster-> 477
#
# wifi, hang_friend, always_crowd
#
# cluster-> 478
#
# laptop, tablet, ipad, tesco, harry_potter, south_africa
#
# cluster-> 479
#
# starbucks, mcdonalds, restraunt
#
# cluster-> 480
#
# internet, after_read, online, web, website, google, page, have_see
#
# cluster-> 481
#
# kings_cross, early_week, time_week, sister_restaurant, victoria_station, different_branch
#
# cluster-> 482
#
# clearly_train, step, leave_stand, unwelcom
#
# cluster-> 483
#
# accommodation, book_afternoon_tea, food_unbelievable, experience_round, leisure
#
# cluster-> 484
#
# spoil_choice, daily_special, choice_menu, different_flavour, plenty_choice, difficult_choose, menu_plenty, menu_choice, fish_lover, kid_enjoy, present_taste
#
# cluster-> 485
#
# fault, absolutely_outstanding, speed_service, interactive_table, waiter_attend, attentive_overpower, arrive_promptly
#
# cluster-> 486
#
# high, bite_high, price_slightly, little_high, consider_location
#
# cluster-> 487
#
# sweet_potatoe, chicken_burger, steak_chip, onion_ring, fry, chip, triple_cook, fish_n, chips, hand_cut
#
# cluster-> 488
#
# pipe_hot, bread, butter, cheese, seasonal_fruit, vegetable, cheese_ball, mac_n, goat_cheese
#
# cluster-> 489
#
# free_water, glass_rise, complimentary, end_have, bellini
#
# cluster-> 490
#
# kitchen, tell_stand, stand_minute, sit_kitchen
#
# cluster-> 491
#
# package, include_bill, la_gavroche, plus_drink
#
# cluster-> 492
#
# slow_service, the_negative, what_shame, -PRON-_suppose, actual, over_price, so_overall
#
# cluster-> 493
#
# parent, special_birthday, husband_birthday
#
# cluster-> 494
#
# explain_situation, manager_tell, coat_bag, go_upstairs, not_care, carnegie, westin, stay_long, queue_minute, politely_ask
#
# cluster-> 495
#
# place_dubai, neighbourhood, athmosphere, right_near, leicester_square, be_time, friday_brunch, strongly_recommend, north_london, vietnamese_restaurant, do_miss, gramercy_tavern
#
# cluster-> 496
#
# super, really
#
# cluster-> 497
#
# break, tire_hungry, hour_late
#
# cluster-> 498
#
# hour_half, till, until, hour_arrive, til
#
# cluster-> 499
#
# certain_time, table_reserve, luckily, sit_right, fortunately, bite_late, pm_reservation, walk_in
#
# cluster-> 500
#
# see_people, this_happen, save, do_waste, pay_tip, forget_book, be_prepare, hour_minute, take_month
#
# cluster-> 501
#
# sight_see, day_advance, central, borough_market, village, for_year
#
# cluster-> 522
#
# travel_orlando, universal, regular_occurrence, lot_interest, typical_american
#
# cluster-> 523
#
# number, online_book, waiter_attention
#
# cluster-> 524
#
# party_member, mineral_water, requirement, mandatory, restriction
#
# cluster-> 525
#
# social_medium, honour, madinat, currently, blue_duck
#
# cluster-> 526
#
# minimum_spend, peak_hour, availability, avoid_queue, ahead_time, the_bouncer
#
# cluster-> 527
#
# book_system, ring, security_check, park_space, coat_leave
#
# cluster-> 528
#
# book_monday, non_french, food_intolerance, specific, specify, reason_star
#
# cluster-> 529
#
# raise_voice, confuse, disturb, interfere, annoy, interrupt, threaten, intimidate, offend, irritate, frighten, bad_word, there_real, embarrass
#
# cluster-> 530
#
# from_moment, moment, sure_happy, forget_ask
#
# cluster-> 531
#
# large_variety, criticise, single_dish, focus, concentrate, emphasis, menu_balance
#
# cluster-> 532
#
# indian_chinese, modern_twist, example, instance, for_instance, chef_prepare, japanese_dish, pick_choose, perfectly_execute, flavour_taste
#
# cluster-> 533
#
# quality_quantity, price_wise, great_deal, especially_consider, average_price, very_expensive, upmarket_restaurant, very_enjoyable
#
# cluster-> 534
#
# pool_area, tube, parking_available
#
# cluster-> 535
#
# dubai_fountain, butter_garlic, padron_pepper, sea, croqueta, duck_pancake, bite_size, perfect_blend, grill_perfection
#
# cluster-> 536
#
# wash, spin-dry_ice, serve_traditional, complimentary_bread, rice_naan, line_fish
#
# cluster-> 537
#
# baby, infant, mama, ravioli_dish, little_boy
#
# cluster-> 538
#
# luggage, handbag, passport
#
# cluster-> 539
#
# stroller, grimaldi, after_long, ride, hop, special_trip, walk_block, sure_reservation, day_park, bike, wheelchair, moto
#
# cluster-> 540
#
# overall_nice, the_downside, all_pleasant, a_enjoyable, overall_enjoyable, an_excellent, another_great
#
# cluster-> 541
#
# improve, enhance, refine
#
# cluster-> 542
#
# need_improvement, proper, authentic_thai, top_quality, good_solid, indian_style, well_town, look_authentic
#
# cluster-> 543
#
# possibly, away_box
#
# cluster-> 544
#
# driver, wheel, from_point, eventually_manage, credit
#
# cluster-> 545
#
# security_guard, fix, rectify, tell_rude
#
# cluster-> 546
#
# wine_list, sommelier, wine, wines, pinot_noir, chardonnay, merlot, sauvignon_blanc, prosecco
#
# cluster-> 547
#
# nice_clean, beautifully_decorate, lovely_decor, pleasant_staff, modern_style, clean_fresh, decor_nice, absolutely_beautiful, beautiful_set, beautiful_interior, lovely_set, upper_street, great_buzz
#
# cluster-> report, tip_waiter, customer_feedback, different_age, duty_manager, staff_genuinely, if_read, manager_give, -PRON-_grateful, photo_wall, self, act, blind
#
# cluster-> 574
#
# door_man, pot_luck, waiter_appear, slight, sharp, male_female, one_star, young_couple
#
# cluster-> 575
#
# necessary, -PRON-_gripe, adequate, inadequate, appropriate, some_staff, match_standard, really_impress
#
# cluster-> 576
#
# equally, similarly, beautiful_presentation
#
# cluster-> 577
#
# greenwich, new_york_city, chinatown, new_yorker, wild_honey, washington_dc, little_india, family_favorite, place_mumbai, visit_regularly, restaurant_orlando, what_find
#
# cluster-> 578
#
# round_corner, place_near, minute_away, stand_outside, shoreditch
#
# cluster-> 579
#
# traditional, authentic, usual_indian
#
# cluster-> 580
#
# sardinian, farm_table, opinion_well, original, there_different, slightly_different, locally_source, -PRON-_objection, south_american
#
# cluster-> 581
#
# classic_dish, genuine, genuinely, knowledgable_staff, italian_cuisine, please_eye, friendly_enthusiastic, perfect_balance
#
# cluster-> 582
#
# corner_table, picture, photo, photograph, round_table, river_view, image, lady_take
#
# cluster-> 583
#
# order_extra, expensive_item, arrive_cold, paper, when_complain, cold_hard, spatchcock_chicken, steak_tough
#
# cluster-> 584
#
# keep_warm, middle, dine_partner, table_dirty, fry_chip, shop_buy
#
# cluster-> 585
#
# metro, metropolitan, brooklyn_bridge, urban
#
# cluster-> 586
#
# item_menu, limit_menu, exception, utterly_delicious, red_meat, unable_eat, add_extra, portion_adequate
#
# cluster-> 587
#
# lunchtime, overnight, midday, weekday_lunch
#
# cluster-> 588
#
# business_lunch, difficult_table, lunch_dinner, especially_child
#
# cluster-> 589
#
# shout, yell, scream
#
# cluster-> 590
#
# little_spin-dry, sauce, meat, potato, fry_rice, chicken, pork, lamb, beef, mix_grill, lamb_chop
#
# cluster-> 591
#
# fresh_juice, italian_vibe, breakfast_option, vegan_option, fresh_produce
#
# cluster-> 592
#
# suitable, sandwich_coffee
#
# cluster-> 593
#
# tray, fridge, freezer, jar, drawer, wallet, pocket, spoon
#
# cluster-> 594
#
# tell_waiter, dirty_plate, nearly, fairly_quickly, almost, ask_water
#
# cluster-> 595
#
# downside, upside, small_size
#
# cluster-> 596
#
# class_restaurant, opinion, price_expensive, cheap_pay, nothing_special
#
# cluster-> 597
#
# near_entrance, single, rest_room, nearby_table, form, a_complete
#
# cluster-> 598
#
# daily, weekly, range_option, special_offer, sweet_savoury, evening_standard, child_menu
#
# cluster-> 599
#
# ...
#
# when_walk, overlook
#
# cluster-> 670
#
# terrible_service, badly, poorly, horribly
#
# cluster-> 671
#
# dempsey_hill, st, rd, th, nd, park_lane, locate_quiet
#
# cluster-> 672
#
# absolutely_shock, uninterested_staff, attention_waiter, restaurant_nearby, thank_god, open_mind, restaurant_cape_town, pub_london, say_let
#
# cluster-> 673
#
# refill_drink, sufficient, enough, very_limit
#
# cluster-> 674
#
# deliver_table, literally, little_confuse, see_waiter, bill_leave, practically
#
# cluster-> 675
#
# basically, essentially
#
# cluster-> 676
#
# ground, parisian_style, look_river
#
# cluster-> 677
#
# space_table, hide, brick_lane
#
# cluster-> 678
#
# handy, prompt_service, tip_book, set_summer, busy_noisy
#
# cluster-> 679
#
# useful, crowd_weekend, plus_point, valuable, helpful_efficient, informative, worthwhile, pun_intend, practical, sensible, straightforward
#
# cluster-> 680
#
# detail, open_kitchen
#
# cluster-> 681
#
# dietary_requirement, express, during_visit
#
# cluster-> 682
#
# sign, people_turn
#
# cluster-> 683
#
# furniture, wood, tile, exterior, marble, brick
#
# cluster-> 684
#
# impressive, restaurant_breathtaking, absolutely_spot
#
# cluster-> 685
#
# wine_bottle, waitress_keep, licence, tap, bottle_beer, theme_night, perfect_compliment, couple_bottle, immediately_give, table_pour
#
# cluster-> 686
#
# cook, steak_nicely, overcook
#
# cluster-> 687
#
# rasika, new_restaurant, disney_world, jaleo, wife_daughter, recent_visit
#
# cluster-> 688
#
# chez_bruce, al_qasr, morning_breakfast, really_recommend, local_area, choice_tea, defo_recommend, young_people, savoury_sweet
#
# cluster-> 689
#
# despite_fact, attitude_staff, duty, popular_venue, guy_take, vacate_table
#
# cluster-> 690
#
# pay_cash, park_lot, roll_eye, universal_studios, team_member, hotel_room
#
# cluster-> 691
#
# poor_review, action, queue_system, expect_crowd, line_people
#
# cluster-> 692
#
# office, walk_straight
#
# cluster-> 693
#
# entree, appetizer, pasta, soup, salad, caesar_salad, broccoli, spinach
#
# cluster-> 694
#
# experience_life, actually_eat, previous, last, highly_disappoint
#
# cluster-> 695
#
# compare, comparison, comparable, compare_restaurant, contrast
#
# cluster-> 696
#
# get_impression, manner, constantly, continually, continuously, assistant_manager, translate_menu
#
# cluster-> 697
#
# wake, walk_street, midst
#
# cluster-> 698
#
# feature, a_beautiful, great_addition, like_film, newly_refurbish, look_thames
#
# cluster->decline, increase, turnaround, rise, decrease, discount_bill, send_email
#
# cluster-> 723
#
# major, past_week, do_not, family_operate, there_reason, keep_mind
#
# cluster-> 724
#
# certain, fair_share
#
# cluster-> 725
#
# the_actual, large_numb, mainly, mostly, primarily, largely, predominantly, partly, this_branch, carefully_choose
#
# cluster-> 726
#
# absolutely_love, excite_try, stay_london, highly_highly_recommend
#
# cluster-> 727
#
# table_space, comfortable_seat, restaurant_clean, staff_courteous, friendly_fast, accomodat
#
# cluster-> 728
#
# cost_extra, round, lovely_meal, bottle_red, view_fantastic, piano_player
#
# cluster-> 729
#
# spoil_even, -PRON-_criticism, careful, cautious, wary, mindful, carefully, beware, so_summary
#
# cluster-> 730
#
# chicago, washington, florida, miami, texas, california, georgia, mexico, capitol_hill
#
# cluster-> 731
#
# menu_post, screen, seat_outside
#
# cluster-> 732
#
# neighbour_table, u_not, seriously, say_goodbye, lightly, very_disappoint
#
# cluster-> 733
#
# budget, yes_bite, end_spend, plus_tip
#
# cluster-> 734
#
# sea_food, veggie, vegetarian, vegan, veg, vegetarian_vegan, vegan_vegetarian, gluten_free, vegetarian_dish
#
# cluster-> 735
#
# shoe, sock
#
# cluster-> 736
#
# appoint, appointment, hire, designate, assign, oversee, propose, take_note, dismiss
#
# cluster-> 737
#
# replace, replacement, woman_come, throw
#
# cluster-> 738
#
# surround, beautiful_inside
#
# cluster-> 739
#
# whenever_-PRON-, son_birthday, go_to, buddakan, sure_expect, whenever, anytime, if_area, visit_dc, trip_nyc, special_celebration, multiple_time, celebration_meal
#
# cluster-> 740
#
# separate, min_wait, two
#
# cluster-> 741
#
# range_different, food_compensate, order_load, individual, day_age
#
# cluster-> 742
#
# foot, table_terrace, party_seat
#
# cluster-> 743
#
# tall, worth_weight, coat_check, -PRON-_presume, big_issue
#
# cluster-> 744
#
# list, extensive_wine, base_location, check_website, next_time
#
# cluster-> 745
#
# life, well_chinese, restaurant_world
#
# cluster-> 746
#
# -PRON-_admit, take_family, benare, 2_visit, travel_london, steakhouse_london, vito, separate_occasion, nopi
#
# cluster-> 747
#
# system, result, consequence
#
# cluster-> 748
#
# drop, fall, jump, sink, slip, what_waste, slide, climb, bounce, drag, typical_london
#
# cluster-> 749
#
# bombay, taj, ganesh, asia_de, bengali, frankie, chole, paulo, havana, rahul
#
# cluster-> bombil_fry, get_to, bar_boulud, insanely_good
#
# cluster-> 779
#
# convenience, future_visit
#
# cluster-> 780
#
# hassle, reservation_advance
#
# cluster-> 781
#
# this_2, look_forward, near_future, can_wait, twice_day, will_surely, on_2, bella_italia, -PRON-_shall, afternoon_tea_ritz, first_time
#
# cluster-> 782
#
# non_stop, jam_pack, quiet_night
#
# cluster-> 783
#
# constantia, block_away, shantaram, long_ago, seven_year, hell_kitchen, step_away, review_disappoint, open_day, clothe, huge_line, reservation_early, find_cozy
#
# cluster-> 784
#
# information, offer_help, show_care
#
# cluster-> 785
#
# info, sure_ask
#
# cluster-> 786
#
# contact, reservation_month, confirm_reservation
#
# cluster-> 787
#
# pizza_lover, little_surprise, picky, fussy, fussy_eater, picky_eater, carmines, french_cuisine, simple_menu, fond, actually_feel
#
# cluster-> 788
#
# double, triple, salad_chip, side_mash, to_accompany, generous_serve, bread_butter, while_eat, be_usually
#
# cluster-> 789
#
# dish, unusual_dish, different_dish
#
# cluster-> 790
#
# all_dish, signature_dish, different_taste, combination, quality_product, pack_flavour, lot_flavour, balance_flavour, interest_combination
#
# cluster-> 791
#
# bonus, brilliant_even, view_breathtaking, day_week
#
# cluster-> 792
#
# enjoy_even, especially_manager, experience_memorable, serve_smile, bar_team, franz, smile_face, thank_team, professional_thank
#
# cluster-> 793
#
# supply, able_choose
#
# cluster-> 794
#
# sense, a_shame
#
# cluster-> 795
#
# opportunity, stop_drink, dishoom, will_able
#
# cluster-> 796
#
# word, phrase, understand_english
#
# cluster-> 797
#
# management_change, quot, barbeque_nation, learn_lot, people_write
#
# cluster-> 798
#
# go_extra, mr, staff_specially, team_thank, christy, thank_u, thank_mr
#
# cluster-> 799
#
# service_industry, ruin_even, party_reservation, effort, previous_review, londons, manager_apologise
#
# cluster-> 800
#
# con, mix_veg, remain_favorite, steak_grill, far_cry, rich_sauce, roast_red, salt_amp, traditional_dish
#
# cluster-> 801
#
# encounter, right_direction, special_even, patronise, worthwhile_experience, busy_city
#
# cluster-> 802
#
# decide_visit, special_event, trip_paris, visit_week, petrus, get_right, have_twice, shaka_zulu, feel_totally, business_associate
#
# cluster-> 803
#
# buzzy_atmosphere, love_decor, place_hangout, business_meeting, breakfast_brunch, greek_restaurant, lady_night, summer_menu
#
# cluster-> 804
#
# special_mention, happy_help, know_stuff, very_attentive, will_soon, many_thank, right_attention, such_lovely, organisation, moment_walk, support
#
# cluster-> 805
#
# limited, bite_limit, sparse
#
# cluster-> 806
#
# david, win_hand, star_michelin, consistent, well_mexican, well_thai
#
# cluster-> 833
#
# immaculate, immaculately, service_match
#
# cluster-> 834
#
# tidy, presentable, atmosphere_warm
#
# cluster-> 835
#
# authentic_indian, japanese_food, indian_cuisine, indian_food, cuisine, cusine, fresh_seasonal, fusion_cuisine, chinese_thai
#
# cluster-> 836
#
# awesome_view, site_see, location_central, right_heart, popular_place
#
# cluster-> 837
#
# special_night, hotel_beautiful, price_decent, business_pleasure, return_thank, two_thumb, server_name, place_highly, perfect_even, fun_even
#
# cluster-> 838
#
# uber, ultra, charm_old, hipster
#
# cluster-> 839
#
# town_decide, hit, super_crowd, able_find, queue_seat, planet_hollywood
#
# cluster-> 840
#
# adjacent, adjoin
#
# cluster-> 841
#
# counter, salad_counter, clean_cutlery
#
# cluster-> 842
#
# ask_refill, free_charge, sparkle_water, dirty_glass, vouch_deal, order_additional, free_cocktail
#
# cluster-> 843
#
# suit, accommodate_large
#
# cluster-> 844
#
# plenty_room, uncomfortable, awkward, busy_night, white_apron, inconvenient, costly, useless
#
# cluster-> 845
#
# king_cross, brixton, piccadilly_circus, international_drive, south_kensington, kensington
#
# cluster-> 846
#
# australia, canada, mac, ms, ca, simon, jonathan
#
# cluster-> 847
#
# beautifully, wonderfully, exquisitely, elegantly, expertly, superbly, finely, excellently, sauce_perfectly
#
# cluster-> 848
#
# nicely, neatly, perfectly_prepare, sound_odd
#
# cluster-> 849
#
# air, seat_floor
#
# cluster-> 850
#
# switch, flip, adjust
#
# cluster-> 851
#
# n, must_try, love_bbq, sichuan, rogan, bbq_pork
#
# cluster-> 852
#
# polite_smile, praise, kudos, thumb_guy
#
# cluster-> 853
#
# minimum, party_size, pretty_decent, max, maximum, truly_awesome, deal_include, keep_check, reservation_necessary, there_limit
#
# cluster-> 854
#
# city_walk, first_thing
#
# cluster-> 855
#
# pizza, pizzas, wood_fire, pizzeria, thin_base, well_pizza, crust_thin, fire_ice, thin_crust, pizza_huge
#
# cluster-> 856
#
# reaction, feedback, treat_respect
#
# cluster-> 857
#
# traveler, shopper, kulcha_king, foodie, hotelier
#
# cluster-> 858
#
# destination, locale
#
# cluster-> 859
#
# fee, surcharge
#
# cluster-> 860
#
# cold_tasteless, describe, describe_menu, define, nothing_wrong, chettinad
#
# cluster-> 861
#
# advertise, charge_add
#
# cluster-> 862
#
# menu_board, basis, some_dish, admit_-PRON-, numb_item, as_far, this_probably, bread_stale
#
# cluster-> 863
# sail, cruise, andina, go_weekend
#
# cluster-> 888
#
# secure, promptly_show, obtain, protect, busy_sunday
#
# cluster-> 889
#
# cheese_plate, mac_amp, top, cheese_meat, white_wine, crust_perfect, to_finish
#
# cluster-> 890
#
# accord, compromise
#
# cluster-> 891
#
# sheet, serviette
#
# cluster-> 892
#
# cardboard, waste, rubbish, trash, dump, bin, crap, clutter
#
# cluster-> 893
#
# unit, brigade, house_beer, taste_okay
#
# cluster-> 894
#
# operation, operate, exist, employ
#
# cluster-> 895
#
# department, cast_member
#
# cluster-> 896
#
# congenial, hospitable, helpful_provide
#
# cluster-> 897
#
# world_war, degree, al_fresco_dine
#
# cluster-> 898
#
# cut, chop, bite_tough
#
# cluster-> 899
#
# medium_rare, steak, rib_eye, steaks, porterhouse, filet_mignon, filet, sirloin, fillet_steak, ribeye
#
# cluster-> 900
#
# slice, roll, bbq_beef, cook_fresh, vegetable_spring
#
# cluster-> 901
#
# england, chelsea, fulham, barcelona, manchester, diego, coz, bentley, holland, southgate
#
# cluster-> 902
#
# functional, care_attention, aspect_restaurant
#
# cluster-> 903
#
# colourful, simple_elegant, color, palette, purple
#
# cluster-> 904
#
# stain, sticky, dye
#
# cluster-> 905
#
# brown, white, black, red, orange, pink, all_wash, smoke_duck, green_tea, brown_onion, mix_vegetable, yellow, blue
#
# cluster-> 906
#
# paint, painting
#
# cluster-> 907
#
# meat_tough, serve_raw, sound_little, contain, sauce_vegetable, scoop_ice_cream, savoury, soup_day
#
# cluster-> 908
#
# patient, soon_get, take_picture
#
# cluster-> 909
#
# mcdonald, ave, fl, ta, camden, albert, notre_dame, tommy, cambridge
#
# cluster-> 910
#
# mix, mixture, blend, spice_flavour, meat_vegetable, bread_base, filet_cook, shrimp_lobster, steam_fish
#
# cluster-> 911
#
# palm, palm_tree, cocktail_whilst, canopy, tree, greenery, christmas_tree
#
# cluster-> 912
#
# welcome_warm, greeting, hug, warmly, smiley
#
# cluster-> 913
#
# cute, sexy
#
# cluster-> 914
#
# super_cool, refreshing, refreshingly, delicious_authentic, very_chill, cocktail_delicious, atmosphere_brilliant, cozy_atmosphere, chill_relax
#
# cluster-> 915
#
# lock, table_available
#
# cluster-> 916
#
# ask_seat, gate, fairly_busy
#
# cluster-> 917
#
# menu_card, challenge, task, menu_explain, course_arrive
# cluster-> 940
#
# fair_however, compensate, offset
#
# cluster-> 941
#
# biscuit, yogurt, cereal, oatmeal, peanut_butter, banana
#
# cluster-> 942
#
# eye, ear, hide_view
#
# cluster-> 943
#
# assistance, aid, pleasure_serve
#
# cluster-> 944
#
# ruin, want_ruin
#
# cluster-> 945
#
# utilise, extend, expand, star_deal
#
# cluster-> 946
#
# green, tomato_bread, accompany_sauce
#
# cluster-> 947
#
# inconvenience, embarrassment
#
# cluster-> 948
#
# after_finish, happily, absolutely_lovely, guest_arrive, kid_kid, would_definately, little_difficult
#
# cluster-> 949
#
# would_return, specifically, be_aware, on_visit, costumer_service
#
# cluster-> 950
#
# joke, come_check, get_attention, floor_manager, bad_attitude
#
# cluster-> 951
#
# euro, couple_glass, rand, gbp
#
# cluster-> 952
#
# dream, mzansi, real_treat, friend_rave, celini, soooo_good, truly_authentic, will_regret
#
# cluster-> 953
#
# theatrical, opera, musical, bel_canto, cabaret, classical, artistic, conservatory
#
# cluster-> 954
#
# kathmandu, hammersmith, rain_forest, check_trip_advisor, must_visit, visit_museum, borough_market_area
#
# cluster-> 955
#
# memorable_even, hesitation, trepidation, special_attention
#
# cluster-> 956
#
# journey, trek, excursion, weekend_brunch, experience_truly, sushisamba, first_visit, pleasure_dine
#
# cluster-> 957
#
# mini, fresh_green, ice_cream_chocolate, red_onion, portion_share, new_potato, red_cabbage, brown_bread
#
# cluster-> 958
#
# bay, harbor, location_right, hout_bay
#
# cluster-> 959
#
# sun_set, the_shard, sunset, clear_day, sunrise, sunset_london, late_afternoon
#
# cluster-> 960
#
# voucher, wowcher, virgin_experience, gift_voucher
#
# cluster-> 961
#
# refresh, pre_meal, veg_dish, extensive_menu, look_appeal, fellow_diner
#
# cluster-> 962
#
# map, sketch, chart, absolute_gem, dot
#
# cluster-> 963
#
# season, foie_gra, soft_shell_crab, mash_potato
#
# cluster-> 964
#
# importantly, in_addition, an_overall, defenetly, lively_fun, waitress_friendly
#
# cluster-> 965
#
# entry, tell_ready
#
# cluster-> 966
#
# price_sky, category, award, competition, no_doubt, every_plate, keep_secret, wine_estate
#
# cluster-> 967
#
# fire, light_dim
#
# cluster-> 968
#
# cookie, cupcake, slice_cake, chocolate_dessert
#
# cluster-> 969
#
# folk, jazz, punjabi_food, broadway_tune, finger_food
#
# cluster-> 970
#
# shut, reopen
#
# cluster-> 971
#
# lavender, flower, floral, fragrant, peach, download, special_request, decide_stop, text_table, menu_state, right_choice, the_slight
#
# cluster-> 1009
#
# research, study, open_new, be_glad, fellow_traveler
#
# cluster-> 1010
#
# preference, different_item, dislike
#
# cluster-> 1011
#
# desire, fine_ingredient
#
# cluster-> 1012
#
# la, le, di, de, les, au, et, de_la, del, que, à, du, en, des
#
# cluster-> 1013
#
# concert, gig, dinner_friday, lunch_saturday
#
# cluster-> 1014
#
# continental, continent, north_west, national_chain
#
# cluster-> 1015
#
# rent, landlord, overly_crowd
#
# cluster-> 1016
#
# knock
#
# cluster-> 1017
#
# par, chicken_leg, star_rate, entertain_dinner
#
# cluster-> 1018
# convention, gathering
#
# cluster-> 1019
#
# complementary, eye_catch, gluten_free_vegan, wonderfully_prepare
#
# cluster-> 1020
#
# seating, view_window
#
# cluster-> 1021
#
# summary, description, brief
#
# cluster-> 1022
#
# public, in_summary, paper_towel
#
# cluster-> 1023
#
# rack, shelf, stack, glass_home
#
# cluster-> 1024
#
# louvre, overlook_london
#
# cluster-> 1025
#
# draw, right_opposite, drawing
#
# cluster-> 1026
#
# crew, cast
#
# cluster-> 1027
#
# superior, inferior, attentive_hover, unmatched
#
# cluster-> 1028
#
# terminal, port
#
# cluster-> 1029
#
# soap, vinegar, poppadom, syrup, ginger_beer, sponge, candy
#
# cluster-> 1030
#
# meter, ft, m
#
# cluster-> 1031
#
# memory, thank_hutong, have_previously, daniel_boulud, twice_year, past_month
#
# cluster-> 1032
#
# print, exotic_meat, complain_waitress
#
# cluster-> 1033
#
# cramp, niggle, bad_point, line_door
#
# cluster-> 1034
#
# body, on_way
#
# cluster-> 1035
#
# doorstep, after_have, visit_australia, big_chain
#
# cluster-> 1036
#
# freeze, frozen, skinny_fry
#
# cluster-> 1037
#
# damage, hurt, impact, blow, main_issue, tear, absolutely_disgust, disaster
#
# cluster-> 1038
#
# executive, president, associate, chief, manger, assistant
#
# cluster-> 1039
#
# replenish, absorb, supplement, order_tap
#
# cluster-> 1040
#
# omelette, omelet, omlette
#
# cluster-> 1041
#
# x, hope_soon, that_mean, frendly, one_tip, steam_vegetable, could_ask
#
# cluster-> 1042
#
# frill, well_alternative, service_immaculate, bite_pricy, asian_fusion, people_dress, little_extra
#
# cluster-> 1043

# %%
# Framework as df
df_clusters_framework = []

n=1
for l in clusters_list_of_lists:
    df_clusters_framework.append((n, len(l), l))
    n=n+1

cols = ['tag_no/cluster_no', 'keys_length', 'keys']
df_clusters_labelled_framework = pd.DataFrame(df_clusters_framework, columns = cols)
# df_clusters_labelled

df_clusters_labelled_framework = df_clusters_labelled_framework[df_clusters_labelled_framework['keys_length'] != 1]

# %%
df_clusters_labelled_framework.to_csv('Output_Clustered_Keys.csv')

# %%
# End time
print(datetime.datetime.now())
# Out:
# 2019-08-06 16:52:55.950005

# %%
# total clusters before custom stop words = 634
